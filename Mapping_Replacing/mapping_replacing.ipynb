# %% [markdown]
# Mapping Replacing
#
# By: Josh Navarro
#
# Goal: Learn how to do mapping and replacing in the Jupyter Notebook and using python pandas.
#
# Data: Created by ChatGPT

# %%
# Imports that we will be using
import pandas as pd
import numpy as np

# %%
# Create the data 
df = pd.DataFrame({
    "employee_id": [101, 102, 103, 104, 105, 106, 107, 108, 109, 110,
                    111, 112, 113, 114, 115, 116],

    "employee_name": ["Maya Chen", "Jordan Smith", "Alex Rivera", "Sofia Garcia",
                      "Ethan Brown", "Lena Patel", "Chris Johnson", "Nora Lee",
                      "Daniel Kim", "Ava Wilson", "Marcus Davis", "Isabella Martinez",
                      "Noah Thompson", "Grace Nguyen", "Olivia Moore", "Elijah Brooks"],

    "department_code": ["HR", "IT", "FIN", "MKT", "IT", "HR", "OPS", "FIN",
                        "MKT", "IT", "OPS", "HR", "FIN", "MKT", "IT", "OPS"],

    "department_name": ["human resources", "Information Tech", "Finance", "marketing",
                        "IT", "Human Resources", "operations", "FINANCE",
                        "Marketing Dept", "information technology", "Ops", "HR",
                        "financial services", "MKT", "Info Tech", "Operations"],

    "employment_type": ["FT", "PT", "Contract", "Full-Time", "Part Time", "FT",
                        "contractor", "Full Time", "PT", "Part-Time", "FT",
                        "Temporary", "Contract", "full-time", "part time", "Temp"],

    "performance_rating": ["Excellent", "Good", "Average", "Poor", "Good",
                           "Excellent", "Avg", "Needs Improvement", "Poor",
                           "Good", "Excellent", "Average", "Avg", "Needs Improvement",
                           "Good", "Poor"],

    "office_location": ["LA", "Los Angeles", "L.A.", "New York", "NY",
                        "San Francisco", "SF", "S.F.", "Los Angeles", "LA",
                        "New York City", "NYC", "San Fran", "SF", "L.A.", "NY"],

    "salary_band": ["A", "B", "C", "B", "A", "C", "D", "B",
                    "C", "A", "D", "B", "C", "A", "B", "D"],

    "remote_status": ["Y", "N", "Yes", "No", "y", "n", "Remote", "Onsite",
                      "Hybrid", "H", "yes", "no", "remote", "onsite", "hybrid", "h"]
})

df
# Out:
#     employee_id      employee_name department_code         department_name  \
# 0           101          Maya Chen              HR         human resources
# 1           102       Jordan Smith              IT        Information Tech
# 2           103        Alex Rivera             FIN                 Finance
# 3           104       Sofia Garcia             MKT               marketing
# 4           105        Ethan Brown              IT                      IT
# 5           106         Lena Patel              HR         Human Resources
# 6           107      Chris Johnson             OPS              operations
# 7           108           Nora Lee             FIN                 FINANCE
# 8           109         Daniel Kim             MKT          Marketing Dept
# 9           110         Ava Wilson              IT  information technology
# 10          111       Marcus Davis             OPS                     Ops
# ...

# %% [markdown]
# Mapping and Replacing
#
# Mapping refers to converting values from one form into another form. Then replacing means changing the old values into the new values.

# %% [markdown]
# 1 Mapping values with .map()

# %% [markdown]
# 2 Replacing values with .replace()

# %% [markdown]
# 3 Replace multiple values in one column

# %% [markdown]
# 4 Standardizing text before mapping

# %% [markdown]
# 5 Mapping number from categories

# %% [markdown]
# 6 Mapping Salary Bands

# %% [markdown]
# 7 Mapping yes/no values

# %% [markdown]
# 8 Using .fillna() after .map()

# %% [markdown]
# 9 Using .replace() across the whole DataFrame

# %% [markdown]
# 10 Using .rename() to replace column names

# %% [markdown]
# 11 Using .where() to replace values conditionally

# %% [markdown]
# 12 Using .mask() to replace values conditionally

# %% [markdown]
# 13 Using .str.replace() for partial text replacement

# %% [markdown]
# 14 Checking your values before and after replacing
