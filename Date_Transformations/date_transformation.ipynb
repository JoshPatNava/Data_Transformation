# %% [markdown]
# Date Transformations
#
# By: Josh Navarro
#
# Goal: Learn how to do Date Transformation in Jupyter Notebook, using Python Pandas
#
# Data: Created by ChatGPT

# %%
# Imports that I will be using
import pandas as pd
import numpy as np

# %%
# Data the will be used
df = pd.DataFrame({
    "order_id": [2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
                 2011, 2012, 2013, 2014, 2015, 2016],
    
    "customer_name": ["Maya Chen", "Jordan Smith", "Alex Rivera", "Sofia Garcia",
                      "Ethan Brown", "Lena Patel", "Chris Johnson", "Nora Lee",
                      "Daniel Kim", "Ava Wilson", "Marcus Davis", "Isabella Martinez",
                      "Noah Thompson", "Grace Nguyen", "Olivia Moore", "Elijah Brooks"],
    
    "order_date": ["2026-01-05", "2026-01-08", "01/14/2026", "2026/01/22",
                   "Feb 03 2026", "2026-02-11", "02/18/2026", "2026-02-28",
                   "2026-03-04", "March 10, 2026", "2026-03-15", "03/21/2026",
                   "2026-04-02", "Apr 09 2026", "2026/04/17", "2026-04-29"],
    
    "ship_date": ["2026-01-07", "2026-01-12", "01/17/2026", "2026/01/25",
                  "Feb 05 2026", "2026-02-15", "02/23/2026", "2026-03-03",
                  "2026-03-07", "March 14, 2026", "2026-03-18", "03/26/2026",
                  "2026-04-06", "Apr 12 2026", "2026/04/22", "2026-05-03"],
    
    "delivery_date": ["2026-01-10", "2026-01-16", "01/20/2026", "2026/01/29",
                      "Feb 08 2026", "2026-02-19", "02/27/2026", "2026-03-06",
                      "2026-03-11", "March 18, 2026", "2026-03-23", "03/30/2026",
                      "2026-04-10", "Apr 16 2026", "2026/04/27", "2026-05-08"],
    
    "sales_amount": [320, 185, 540, 760, 245, 410, 150, 890,
                     275, 630, 480, 210, 950, 375, 690, 520],
    
    "membership_start": ["2025-08-15", "2024-11-03", "2025-01-20", "2023-09-10",
                         "2025-12-01", "2024-06-18", "2026-01-05", "2023-03-22",
                         "2025-07-30", "2024-02-14", "2025-04-09", "2026-02-01",
                         "2023-12-11", "2024-09-25", "2025-10-05", "2024-05-17"]
})

df
# Out:
#     order_id      customer_name      order_date       ship_date  \
# 0       2001          Maya Chen      2026-01-05      2026-01-07
# 1       2002       Jordan Smith      2026-01-08      2026-01-12
# 2       2003        Alex Rivera      01/14/2026      01/17/2026
# 3       2004       Sofia Garcia      2026/01/22      2026/01/25
# 4       2005        Ethan Brown     Feb 03 2026     Feb 05 2026
# 5       2006         Lena Patel      2026-02-11      2026-02-15
# 6       2007      Chris Johnson      02/18/2026      02/23/2026
# 7       2008           Nora Lee      2026-02-28      2026-03-03
# 8       2009         Daniel Kim      2026-03-04      2026-03-07
# 9       2010         Ava Wilson  March 10, 2026  March 14, 2026
# 10      2011       Marcus Davis      2026-03-15      2026-03-18
# 11      2012  Isabella Martinez      03/21/2026      03/26/2026
# 12      2013      Noah Thompson      2026-04-02      2026-04-06
# 13      2014       Grace Nguyen     Apr 09 2026     Apr 12 2026
# ...

# %% [markdown]
# Date Transformations

# %%
# Copy the data
date_df = df.copy()
# Check the data
date_df.columns
# Out:
# Index(['order_id', 'customer_name', 'order_date', 'ship_date', 'delivery_date',
#        'sales_amount', 'membership_start'],
#       dtype='object')

# %% [markdown]
# 1 Convert text dates using the pd.to_datetime()

# %% [markdown]
# 2 Extract the year

# %% [markdown]
# 3 Extract the month number

# %% [markdown]
# 4 Extract the month name

# %% [markdown]
# 5 Extract the day of the week

# %% [markdown]
# 6 Extract the quarter

# %% [markdown]
# 7 Extract day, week, and day of year

# %% [markdown]
# 8 Calculate the difference between dates

# %% [markdown]
# 9 Convert date differences into the number of days

# %% [markdown]
# 10 Create a date-based conditional column

# %% [markdown]
# 11 Use np.select() for multiple data categories

# %% [markdown]
# 12 Find how long ago something happened

# %% [markdown]
# 13 Filter rows by dates

# %% [markdown]
# 14 Sort by the dates

# %% [markdown]
# 15 Group by date parts

# %% [markdown]
# 16 Create a year month column

# %% [markdown]
# 17 Format dates as text using .dt.strftime()

# %% [markdown]
# 18 Handle invalid dates with errors = "coerce"

# %% [markdown]
# 19 Get minimum and maximum dates
